# %% [markdown]
# # Lab-1 Set-up

# %% [markdown]
# ## Conda Environment
# Course-specific conda environment created and activated via terminal:
# * \$ conda create --name e611 python=3.8
# * \$ conda activate e611
# * \$ conda install -c conda-forge graphviz python-graphviz
# * \$ conda install -c districtdatalabs yellowbrick=1.5
# * \$ pip install mglearn
#
# Note: Conda environment with python 3.10 would not allow installation of yellowbrick on my M1

# %%
import sys
print("Python version:", sys.version)
import pandas as pd
print("pandas version:", pd.__version__)
import matplotlib
print("matplotlib version:", matplotlib.__version__)
import numpy as np
print("NumPy version:", np.__version__)
import scipy as sp
print("SciPy version:", sp.__version__)
import IPython
print("IPython version:", IPython.__version__)
import sklearn
print("scikit-learn version:", sklearn.__version__)
import yellowbrick
print("yellowbrick version:", yellowbrick.__version__)
# Out:
# Python version: 3.8.13 (default, Mar 28 2022, 06:13:39)
# [Clang 12.0.0 ]
# pandas version: 1.5.0
# matplotlib version: 3.5.2
# NumPy version: 1.21.5
# SciPy version: 1.7.3
# IPython version: 8.3.0
# scikit-learn version: 1.1.1
# yellowbrick version: 1.5

# %%
#listing conda environments
# !conda env list
# Out:
# # conda environments:
# #
# base                     /Users/uoc/opt/anaconda3
# e611                  *  /Users/uoc/opt/anaconda3/envs/e611
# ensf592                  /Users/uoc/opt/anaconda3/envs/ensf592

# %%
#listing e611 environment packages 
# (python, pandas, matplotlib, numpy, scipy, IPython, skcikit-learn, yellowbrick, graphviz, mglearn)
# !conda list
# Out:
# # packages in environment at /Users/uoc/opt/anaconda3/envs/e611:
# #
# # Name                    Version                   Build  Channel
# appnope                   0.1.2           py38hca03da5_1001    anaconda
# argon2-cffi               21.3.0             pyhd3eb1b0_0    anaconda
# argon2-cffi-bindings      21.2.0           py38h1a28f6b_0    anaconda
# asttokens                 2.0.5              pyhd3eb1b0_0    anaconda
# attrs                     21.4.0             pyhd3eb1b0_0    anaconda
# backcall                  0.2.0              pyhd3eb1b0_0    anaconda
# beautifulsoup4            4.11.1           py38hca03da5_0    anaconda
# blas                      1.0                    openblas
# bleach                    4.1.0              pyhd3eb1b0_0    anaconda
# brotli                    1.0.9                h1a28f6b_7
# brotli-bin                1.0.9                h1a28f6b_7
# ca-certificates           2022.9.14            h4653dfc_0    conda-forge
# ...
